% %% [markdown]
% # I- DESCRIPTION

% %%
qMRinfo('charmed'); % Describe the model

% %% [markdown]
% # II- MODEL PARAMETERS
% ## a- Create object

% %%
Model = charmed;

% %% [markdown]
% ## Download sample data from OSF
% > The current `Model` is an instance of `charmed` class.
%
% You can manually download the sample data for `charmed` [by clicking here](https://osf.io/u8n56/download?version=3).

% %%
dataDir = downloadData(Model,pwd);

% %% [markdown]
% ## b- Set protocol
% > Protocol is set according to the example data
%
% %          |- charmed object needs 1 protocol field(s) to be assigned:
% %          |-   DiffusionData

% %%
Gx = [0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071];
% Gx is a vector of [1791X1]
Gy = [0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.0000; 0.0000; 0.0000; 0.0000; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; -0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071; 0.7071];
% Gy is a vector of [1791X1]
Gz = [0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000; 0.0000];
% Gz is a vector of [1791X1]
Gnorm  = [0.0000; 0.0000; 0.0000; 0.0000; 0.8485; 0.8314; 0.8142; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6942; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6942; 0.7114; 0.7285; 0.7457; 0.7628; 0.7800; 0.7971; 0.8142; 0.8314; 0.8485; 0.8485; 0.8314; 0.8142; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6942; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6942; 0.7114; 0.7285; 0.7457; 0.7628; 0.0000; 0.0000; 0.0000; 0.0000; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628; 0.7800; 0.7971; 0.8143; 0.8314; 0.8485; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628; 0.0000; 0.0000; 0.0000; 0.0000; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628; 0.7800; 0.7971; 0.8143; 0.8314; 0.8485; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628; 0.0000; 0.0000; 0.0000; 0.0000; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628; 0.7800; 0.7971; 0.8143; 0.8314; 0.8485; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628; 0.0000; 0.0000; 0.0000; 0.0000; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628; 0.7800; 0.7971; 0.8143; 0.8314; 0.8485; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628; 0.0000; 0.0000; 0.0000; 0.0000; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628; 0.7800; 0.7971; 0.8143; 0.8314; 0.8485; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628; 0.0000; 0.0000; 0.0000; 0.0000; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628; 0.7800; 0.7971; 0.8143; 0.8314; 0.8485; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628; 0.0000; 0.0000; 0.0000; 0.0000; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628; 0.7800; 0.7971; 0.8143; 0.8314; 0.8485; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628; 0.0000; 0.0000; 0.0000; 0.0000; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628; 0.7800; 0.7971; 0.8143; 0.8314; 0.8485; 0.8485; 0.8314; 0.8143; 0.7971; 0.7800; 0.7628; 0.7457; 0.7285; 0.7114; 0.6943; 0.6771; 0.6600; 0.6428; 0.6257; 0.6085; 0.5914; 0.5743; 0.5571; 0.5400; 0.5228; 0.5057; 0.4885; 0.4714; 0.4543; 0.4371; 0.4200; 0.4028; 0.3857; 0.3685; 0.3514; 0.3343; 0.3171; 0.3000; 0.2828; 0.2657; 0.2486; 0.2314; 0.2143; 0.1971; 0.1800; 0.1628; 0.1457; 0.1286; 0.1114; 0.0943; 0.0771; 0.0600; 0.0429; 0.0257; 0.0086; 0.0086; 0.0257; 0.0429; 0.0600; 0.0771; 0.0943; 0.1114; 0.1286; 0.1457; 0.1628; 0.1800; 0.1971; 0.2143; 0.2314; 0.2486; 0.2657; 0.2828; 0.3000; 0.3171; 0.3343; 0.3514; 0.3685; 0.3857; 0.4028; 0.4200; 0.4371; 0.4543; 0.4714; 0.4885; 0.5057; 0.5228; 0.5400; 0.5571; 0.5743; 0.5914; 0.6085; 0.6257; 0.6428; 0.6600; 0.6771; 0.6943; 0.7114; 0.7285; 0.7457; 0.7628];
% Gnorm (T/m) is a vector of [1791X1]
Delta  = [0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0070; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0120; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0150; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0200; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0250; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0300; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0350; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400; 0.0400];
% Delta (s) is a vector of [1791X1]
delta  = [0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0030; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080; 0.0080];
% delta (s) is a vector of [1791X1]
TE  = [0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0362; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0462; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0473; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0523; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0573; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623; 0.0623];
% TE (s) is a vector of [1791X1]
Model.Prot.DiffusionData.Mat = [ Gx Gy Gz Gnorm  Delta  delta  TE ];
%%

% %% [markdown]
% # III- FIT EXPERIMENTAL DATASET
% ## a- Load experimental data
% %          |- charmed object needs 3 data input(s) to be assigned:
% %          |-   DiffusionData
% %          |-   SigmaNoise
% %          |-   Mask

% %%
% DiffusionData.nii.gz contains [64    64     1  1791] data.
data.DiffusionData=double(load_nii_data('charmed_data/DiffusionData.nii.gz'));
% Mask.nii.gz contains [64  64] data.
data.Mask=double(load_nii_data('charmed_data/Mask.nii.gz'));

% %% [markdown]
% ## b- Fit experimental data
% > This section will fit data.

% %%
FitResults = FitData(data,Model,0);

% %% [markdown]
% ## c- Show fitting results
% > * Output map will be displayed.
%
% > * If available, a graph will be displayed to show fitting in a voxel.

% %%
qMRshowOutput(FitResults,data,Model);

% %% [markdown]
% ## d- Save results
% > * qMR maps are saved in NIFTI and in a structure `FitResults.mat` that can be loaded in qMRLab graphical user interface.
% > * Model object stores all the options and protocol
% > * These objects can be easily shared or be used for simulation.

% %%
FitResultsSave_nii(FitResults, 'charmed_data/DiffusionData.nii.gz');

% %% [markdown]
% # IV- SIMULATIONS
% > This section can be executed to run simulations for vfa_t1.
%
% ## a- Single Voxel Curve
% > Simulates single voxel curves:
%
%        1. Use equation to generate synthetic MRI data
%        2. Add rician noise
%        3. Fit and plot curve

% %%
      x = struct;
      x.fr = 0.5;
      x.Dh = 0.7;
      x.diameter_mean = 6;
      x.fcsf = 0;
      x.lc = 0;
      x.Dcsf = 3;
      x.Dintra = 1.4;
      % Set simulation options
      Opt.SNR = 50;
      % run simulation
      figure('Name','Single Voxel Curve Simulation');
      FitResult = Model.Sim_Single_Voxel_Curve(x,Opt);

% %% [markdown]
% ## b- Sensitivity analysis
% > Simulates sensitivity to fitted parameters:
%
%        1. Vary fitting parameters from lower (lb) to upper (ub) bound.
%        2. Run Sim_Single_Voxel_Curve Nofruns times
%        3. Compute mean and std across runs

% %%
      %              fr            Dh            diameter_mean fcsf          lc            Dcsf          Dintra        
      OptTable.st = [0.5           0.7           6             0             0             3             1.4]; % nominal values
      OptTable.fx = [0             1             1             1             1             1             1]; %vary fr...
      OptTable.lb = [0             0.3           3             0             0             1             0.3]; %...from 0
      OptTable.ub = [1             3             10            1             8             4             3]; %...to 1
      % Set simulation options
      Opt.SNR = 50;
      Opt.Nofrun = 5;
      % run simulation
      SimResults = Model.Sim_Sensitivity_Analysis(OptTable,Opt);
      figure('Name','Sensitivity Analysis');
      SimVaryPlot(SimResults, 'fr' ,'fr' );
